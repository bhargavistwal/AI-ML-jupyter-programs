# %% [markdown]
# # NUMPY PRACTICE

# %% [markdown]
# ## 1. Import Numpy

# %%
import numpy as np

# %% [markdown]
# ## 2. Array Creation

# %%
import numpy as np
arr = np.array([1,2,3,4,5])
print(arr)
# Out:
# [1 2 3 4 5]

# %%
# 1D array
import numpy as np
arr1 = np.array([10,20,30,40,50])
print("1D Array :" , arr1)

# 2D array
import numpy as np
arr2= np.array([[1,2,3],[4,5,6]])
print("2D Array :", arr2)
# Out:
# 1D Array : [10 20 30 40 50]
# 2D Array : [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ## 3. Random Numbers

# %%
import numpy as np
np.random.seed(42)

random_int = np.random.randint(1,100,10)
random_float = np.random.rand(5)

print("random integers :",random_int)
print("random float :",random_float)
# Out:
# random integers : [52 93 15 72 61 21 83 87 75 75]
# random float : [0.86617615 0.60111501 0.70807258 0.02058449 0.96990985]

# %% [markdown]
# ## 4. Mean Average

# %%
import numpy as np
data = np.array([10,20,30,40,50])
print("Data :",data)
print("Mean :",np.mean(data))
# Out:
# Data : [10 20 30 40 50]
# Mean : 30.0

# %% [markdown]
# ## 5. Max , Min , Sum

# %%
import numpy as np
arr = np.array([5,12,8,20,3])

print("Array :", arr)
print("Maximum :",np.max(arr))
print("Minimum :",np.min(arr))
print("Sum :",np.sum(arr))
# Out:
# Array : [ 5 12  8 20  3]
# Maximum : 20
# Minimum : 3
# Sum : 48
